# %% [markdown]
# # MyMDB Analyzer
# This notebook accesses the IMDb-Scraping pipeline consisting of the webscraper, the database connector and provides a GUI for the interactive visualization.
#
# ![IMDb Logo](https://upload.wikimedia.org/wikipedia/commons/thumb/6/69/IMDB_Logo_2016.svg/440px-IMDB_Logo_2016.svg.png)
#
# `Wikipedia IMDb Definition`
#
# IMDb (an acronym for `I`nternet `M`ovie `D`atabase) is an online database of information related to films, television series, podcasts, home videos, video games, and streaming content online – including cast, production crew and personal biographies [...]
#
# This notebook visually explores rankings of movies and actors and

# %%
# workarround for using event_loops in notebooks (ipykernel already uses the global non-reentrant one)
import nest_asyncio
nest_asyncio.apply()
from scraping import scrape_top_movies

# %%
# scrape the top N movies off the charts
movies = scrape_top_movies(30)

# %%
# live-demo safety measure (in-case IMDb gives us a cooldown)
# import pickle

# with open("./moviedata/top3.pkl", "rb") as f:
#     movies = pickle.load(f)
# movies

# %%
# insert results
import db
for movie in movies:
    try:
        db.insert_movie(**movie)
    except:
        print("issue at", movie)
# Out:
# connecting to db via conn_str: DRIVER=SQL Server;SERVER=localhost;PORT=1433;DATABASE=MyMDB;UID=SA;PWD=Pr0dRdyPw!

# %%
db.print_all_tables()
# Out:
# printing table actors
# ...

# %%
# check for duplicates
db.cursor.execute("SELECT name, COUNT(*) from actors GROUP BY NAME HAVING COUNT(*) > 1")
for row in db.cursor.fetchall():
    print(row)

# %%
movies_db = db.select_all("movies")
movies_db = [list(m) for m in movies_db]
import analyze
analyze.get_movie_dataframe(movies_db)
# Out:
#                                                   index      genre rating
# title                                       year
# Die Verurteilten                            1994     61      Drama    9.2
# Der Pate                                    1972     62      Krimi    9.2
# The Dark Knight                             2008     63     Action    9.0
# Der Pate 2                                  1974     64      Krimi    9.0
# Die zwölf Geschworenen                      1957     65      Krimi    9.0
# Schindlers Liste                            1993     66  Biografie    8.9
# Der Herr der Ringe: Die Rückkehr des Königs 2003     67     Action    8.9
# Pulp Fiction                                1994     68      Krimi    8.8
# Der Herr der Ringe: Die Gefährten           2001     69     Action    8.8
# Zwei glorreiche Halunken                    1966     70  Abenteuer    8.8
# Forrest Gump                                1994     71      Drama    8.8
# ...

# %%
import analyze
analyze.get_movie_dataframe(db.select_all("movies"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 import analyze
# ----> 2 analyze.get_movie_dataframe(db.select_all("movies"))
#
# File c:\dev\MyMDB\app\analyze.py:8, in get_movie_dataframe(movies)
#       6 def get_movie_dataframe(movies):
#       7     """ (61, 'Die Verurteilten', 1994, 'Drama', Decimal('9.2') """
# ----> 8     return pd.DataFrame(
#       9             movies, columns=["index", "title", "year", "genre", "rating"],
#      10     ).set_index(["title", "year"])
#
# File c:\Users\NiJoL\anaconda3\envs\MyMDB\lib\site-packages\pandas\core\frame.py:762, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     754         mgr = arrays_to_mgr(
#     755             arrays,
#     756             columns,
#    (...)
#     759             typ=manager,
#     760         )
#     761     else:
# --> 762         mgr = ndarray_to_mgr(
# ...
